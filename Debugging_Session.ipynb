# %% [markdown]
# <a href="https://colab.research.google.com/github/RheaMimiCarillo/skillspire-ai-ml/blob/main/Debugging_Session.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Rhea Mimi Carillo

# %% [markdown]
# # Python Lab
# ## Topics: Dictionaries, data structure conversions.

# %% [markdown]
# 1. Create and display a dictionary with the following key-value pairs:
# - Key: 0, Value: 10
# - Key: 1, Value: 20
# - Key: 2, Value: 30
# - Key: 3, Value: 40
#
# Do so two different times using two different methods.

# %%
# method 1
dictionary = {0:10, 1:20, 2:30, 3:40} # fixed wrong brackets

print("method 1:", dictionary)
# Out:
# method 1: {0: 10, 1: 20, 2: 30, 3: 40}

# %%
# Method 2

# fix: since the keys are a numeric type, we pass an iterable type into the dict() method.
dictionary_2 = dict([(0,10), (1,20), (2,30), (3,40)])
# before: dictionary_2 = dict(0:10, 1:20, 2:30, 3:40)

print("method 2:", dictionary_2)
# Out:
# method 2: {0: 10, 1: 20, 2: 30, 3: 40}

# %% [markdown]
# 2. What is the issue with the following dictionary? (Answer in a Markdown cell.)
#
# `my_dict = {1:10, 2:10, 1:20, 3: 10}`

# %% [markdown]
# The problem is that there are duplicate keys in the dictionary literal.

# %% [markdown]
# 3. Use the `get()` method to show the top-selling flavor of the Los Angeles location.

# %%
# This dictionary contains the top-selling ice cream flavor for an ice cream chain with locations in multiple cities.
top_flavors_dict = {'Dallas':'chocolate', 'New York City':'hazlenut', 'Miami':'espresso', 'Los Angeles': 'vanilla'}
## fix: closing bracket was `]` instead of `}`

# Put your code below
print(top_flavors_dict.get('Los Angeles'))

# before: print(top_flavors_dict.get['Los Angeles']) ## found: name of the dictionary is different from the above (flavor vs flavors)

## fixed: typo, ("flavor" vs "flavors")
## fixed changed square brackets on function call to round ones
# Out:
# vanilla

# %% [markdown]
# 4. Accomplish the same task as #3 using a different approach.

# %%
top_flavors_dict = {'Dallas':'chocolate', 'New York City':'hazlenut', 'Miami':'espresso', 'Los Angeles': 'vanilla'}
## fixed: closing bracket changed to `}`
## fixed: removed trailing colon `:`


print(top_flavors_dict.get('Los Angeles'))

# fixed same typo as previous, added parenthesis to function call
# Out:
# vanilla

# %% [markdown]
# 5. What are all the values in `top_flavors_dict`?

# %%
top_flavors_dict.values() # changed _ to .
# Out:
# dict_values(['chocolate', 'hazlenut', 'espresso', 'vanilla'])

# %% [markdown]
# 6. What are all the keys in `top_flavors_dict`?

# %%
top_flavors_dict.keys() # changed function call to .keys()
# Out:
# dict_keys(['Dallas', 'New York City', 'Miami', 'Los Angeles'])

# %% [markdown]
# 7. True or False: We can use slicing in dictionaries. (Answer in a Markdown cell.)

# %% [markdown]
# FALSE. NOT ORDERED.

# %% [markdown]
# 8. Create a nested list, and turn it into a dictionary. Print the dictionary. What is the length of this dictionary?

# %%
nested_list = [["a","apple"],["b","banana"]] # fixed brackets
nested_list_dict = dict(nested_list) # fixed function call
print(nested_list_dict) # fixed typo
print(len(nested_list_dict))

# The length of the dictionary is 2
# Out:
# {'a': 'apple', 'b': 'banana'}
# 2

# %% [markdown]
# 9. Remove the key-value pair associated with Kansas City from this dictionary.

# %%
cities_dict = {1:'Chicago', 2:'Boise', 3:'Las Vegas', 4:'Kansas City', 5:'Boston'} # curly

# Put your code below
cities_dict.pop(4) # used .pop() BIF

print(cities_dict)
# Out:
# {1: 'Chicago', 2: 'Boise', 3: 'Las Vegas', 5: 'Boston'}

# %% [markdown]
# 10. Replace the first city from the dictionary in #9 with the city that you live in.

# %%
cities_dict = {1:'Chicago', 2:'Boise', 3:'Las Vegas', 4:'Kansas City', 5:'Boston'}

cities_dict.update({1: 'Seattle'}) # used .update BIF |

print (cities_dict)
# Out:
# {1: 'Seattle', 2: 'Boise', 3: 'Las Vegas', 4: 'Kansas City', 5: 'Boston'}

# %% [markdown]
# 11. Convert the following dictionary to a list. Make sure the list has the dictionary's keys and values!

# %%
my_dict = {'city1':'Chicago', 'city2':'Boise', 'city3':'Las Vegas'}

# Put your code below
my_dict_list = list(my_dict.items()) # fixed: 'I' instead of 'l' | parens
print(my_dict_list)
# Out:
# [('city1', 'Chicago'), ('city2', 'Boise'), ('city3', 'Las Vegas')]

# %% [markdown]
# 12. Convert the keys of the dictionary from #11 to a tuple.

# %%
my_dict_tuple = tuple(my_dict.keys()) # extra paren | brackets -> curlies | used .keys()
print(my_dict_tuple) # typo
# Out:
# ('city1', 'city2', 'city3')

# %% [markdown]
# 13. Create a nested list (make one up!), then convert it to a dictionary.

# %%
nested_list = [["Ice Cream", "Dr Pepper"], ["Michigan", "Arkansas"]] # changed to string literals
nested_dict = dict(nested_list) # fixed brackets -> parens
print(nested_dict)
# Out:
# {'Ice Cream': 'Dr Pepper', 'Michigan': 'Arkansas'}

# %% [markdown]
# 14. Convert the following tuple to a list.

# %%
my_tup = ((1, 2), (3, 4), (5, 6), (7, 8))

# Put your code below
my_list = list(my_tup) # typo
print(my_list)
# Out:
# [(1, 2), (3, 4), (5, 6), (7, 8)]
